# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import PIL

# %%
from PIL import Image
image1 = Image.open(r'D:\MJCJ research\Hollows_in_walls\Hollows_in_walls\Images\PIA15327.tif')
image1
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=1361x1366 at 0x19B9D751348>

# %%
from PIL import ImageEnhance

applier = ImageEnhance.Brightness(image1)
applier.enhance(0.75).save("PIA15327_brightness_enhanced.tif")

# %%
applier = ImageEnhance.Sharpness(image1)
applier.enhance(1.5).show()

# %%
applier = ImageEnhance.Contrast(image1)
applier.enhance(0.75).show()

# %%
from PIL import ImageFilter

image1.filter(ImageFilter.EDGE_ENHANCE)
# Out:
# <PIL.Image.Image image mode=L size=1361x1366 at 0x19B9D740248>
